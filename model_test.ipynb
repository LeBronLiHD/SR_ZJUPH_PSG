# %%
import utils
import numpy as np
import matplotlib.pyplot as plt
import params
import data_loader

# %%
from models import cnn_1, cnn_2, cnn_lstm, cnn_crf, resnet_101v2, efficient_net_v2l, vgg_19
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import f1_score, accuracy_score, classification_report
from glob import glob
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm
from ann_visualizer.visualize import ann_viz
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import TensorBoard
import tensorboard
import datetime
from tensorflow.keras.utils import plot_model
import visualkeras

# %%
model = cnn_1()
print(model(np.random.random((9, params.UNIT_LENGTH, params.DIMENSION))).shape)
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 30726, 23)]       0
#
#  conv1d_35 (Conv1D)          (None, 30722, 16)         1856
#
#  conv1d_36 (Conv1D)          (None, 30718, 16)         1296
#
#  max_pooling1d_12 (MaxPoolin  (None, 15359, 16)        0
#  g1D)
#
#  spatial_dropout1d_13 (Spati  (None, 15359, 16)        0
#  alDropout1D)
#
#  conv1d_37 (Conv1D)          (None, 15357, 32)         1568
#
#  conv1d_38 (Conv1D)          (None, 15355, 32)         3104
#
#  max_pooling1d_13 (MaxPoolin  (None, 7677, 32)         0
#  g1D)
#
#  spatial_dropout1d_14 (Spati  (None, 7677, 32)         0
#  alDropout1D)
#
#  conv1d_39 (Conv1D)          (None, 7675, 32)          3104
#
#  conv1d_40 (Conv1D)          (None, 7673, 32)          3104
#
#  max_pooling1d_14 (MaxPoolin  (None, 3836, 32)         0
#  g1D)
#
# ...

# %%
model = cnn_2()
print(model(np.random.random((9, 7, params.UNIT_LENGTH, params.DIMENSION))).shape)
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_13 (InputLayer)       [(None, None, 30726, 23)  0
#                              ]
#
#  time_distributed_4 (TimeDis  (None, None, 64)         252176
#  tributed)
#
#  conv1d_84 (Conv1D)          (None, None, 128)         24704
#
#  spatial_dropout1d_31 (Spati  (None, None, 128)        0
#  alDropout1D)
#
#  conv1d_85 (Conv1D)          (None, None, 128)         49280
#
#  dropout_26 (Dropout)        (None, None, 128)         0
#
#  conv1d_86 (Conv1D)          (None, None, 5)           1925
#
# ...
# Total params: 328,085
# Trainable params: 328,085
# Non-trainable params: 0
# _________________________________________________________________
# ...
# (9, 7, 5)

# %%
model = cnn_lstm()
print(model(np.random.random((9, 7, params.UNIT_LENGTH, params.DIMENSION))).shape)
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_15 (InputLayer)       [(None, None, 30726, 23)  0
#                              ]
#
#  time_distributed_5 (TimeDis  (None, None, 64)         252176
#  tributed)
#
#  bidirectional (Bidirectiona  (None, None, 200)        132000
#  l)
#
#  dropout_29 (Dropout)        (None, None, 200)         0
#
#  bidirectional_1 (Bidirectio  (None, None, 200)        240800
#  nal)
#
#  conv1d_95 (Conv1D)          (None, None, 5)           1005
#
# ...
# Total params: 625,981
# Trainable params: 625,981
# Non-trainable params: 0
# _________________________________________________________________
# ...
# (9, 7, 5)

# %%
model = cnn_crf()
print(model(np.random.random((9, 7, params.UNIT_LENGTH, params.DIMENSION))).shape)
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_17 (InputLayer)       [(None, None, 30726, 23)  0
#                              ]
#
#  time_distributed_6 (TimeDis  (None, None, 64)         252176
#  tributed)
#
#  conv1d_104 (Conv1D)         (None, None, 128)         24704
#
#  spatial_dropout1d_38 (Spati  (None, None, 128)        0
#  alDropout1D)
#
#  conv1d_105 (Conv1D)         (None, None, 128)         49280
#
#  dropout_32 (Dropout)        (None, None, 128)         0
#
#  crf (CRF)                   (None, None, 5)           680
#
# ...
# Total params: 326,840
# Trainable params: 326,840
# Non-trainable params: 0
# _________________________________________________________________
# ...
# (9, 7, 5)
